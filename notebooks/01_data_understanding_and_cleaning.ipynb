# %%
import pandas as pd

# %%
netflix_data=pd.read_csv('C:\\Users\\dawit\\PycharmProjects\\Netflix Content Evolution\\data\\netflix_titles.csv')

# %%
netflix_data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix_data.shape
# Out:
# (8807, 12)

# %%
netflix_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 825.8 KB

# %%
for column in netflix_data.columns:
    print(column,netflix_data[column].nunique())
# Out:
# show_id 8807
# type 2
# title 8807
# director 4528
# cast 7692
# country 748
# date_added 1767
# release_year 74
# rating 17
# duration 220
# listed_in 514
# description 8775

# %%
netflix_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
netflix_data['release_year'].unique()
# Out:
# array([2020, 2021, 1993, 2018, 1996, 1998, 1997, 2010, 2013, 2017, 1975,
#        1978, 1983, 1987, 2012, 2001, 2014, 2002, 2003, 2004, 2011, 2008,
#        2009, 2007, 2005, 2006, 1994, 2015, 2019, 2016, 1982, 1989, 1990,
#        1991, 1999, 1986, 1992, 1984, 1980, 1961, 2000, 1995, 1985, 1976,
#        1959, 1988, 1981, 1972, 1964, 1945, 1954, 1979, 1958, 1956, 1963,
#        1970, 1973, 1925, 1974, 1960, 1966, 1971, 1962, 1969, 1977, 1967,
#        1968, 1965, 1946, 1942, 1955, 1944, 1947, 1943])

# %%
netflix_data['release_year'].value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1961       1
# 1959       1
# 1925       1
# 1966       1
# 1947       1
# Name: count, Length: 74, dtype: int64

# %%
netflix_data['date_added'].unique()
# Out:
# <StringArray>
# ['September 25, 2021', 'September 24, 2021', 'September 23, 2021',
#  'September 22, 2021', 'September 21, 2021', 'September 20, 2021',
#  'September 19, 2021', 'September 17, 2021', 'September 16, 2021',
#  'September 15, 2021',
#  ...
#     ' March 31, 2017',     'March 23, 2017',  'December 25, 2016',
#   'November 30, 2016',   'October 23, 2017',   'November 4, 2017',
#      'August 5, 2015',   'December 6, 2018',      'March 9, 2016',
#    'January 11, 2020']
# Length: 1768, dtype: str

# %%
netflix_data['date_added'].value_counts()
# Out:
# date_added
# January 1, 2020      109
# November 1, 2019      89
# March 1, 2018         75
# December 31, 2019     74
# October 1, 2018       71
#                     ...
# November 4, 2017       1
# August 5, 2015         1
# December 6, 2018       1
# March 9, 2016          1
# January 11, 2020       1
# Name: count, Length: 1767, dtype: int64

# %%
netflix_data[netflix_data['date_added'].isna()]
# Out:
#      show_id     type                                        title director  \
# 6066   s6067  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6174   s6175  TV Show              Anthony Bourdain: Parts Unknown      NaN
# 6795   s6796  TV Show                                      Frasier      NaN
# 6806   s6807  TV Show                                      Friends      NaN
# 6901   s6902  TV Show                              Gunslinger Girl      NaN
# 7196   s7197  TV Show                                     Kikoriki      NaN
# 7254   s7255  TV Show                          La Familia P. Luche      NaN
# 7406   s7407  TV Show                                        Maron      NaN
# 7847   s7848  TV Show                                 Red vs. Blue      NaN
# 8182   s8183  TV Show                 The Adventures of Figaro Pho      NaN
#
#                                                    cast         country  \
# ...

# %%
netflix_data=netflix_data[~(netflix_data['date_added'].isna())]
netflix_data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 8797 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8797 non-null   str
#  1   type          8797 non-null   str
#  2   title         8797 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7972 non-null   str
#  5   country       7967 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8797 non-null   int64
#  8   rating        8793 non-null   str
#  9   duration      8794 non-null   str
#  10  listed_in     8797 non-null   str
#  11  description   8797 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 893.4 KB

# %%
netflix_data['date_added'].head()
# Out:
# 0    September 25, 2021
# 1    September 24, 2021
# 2    September 24, 2021
# 3    September 24, 2021
# 4    September 24, 2021
# Name: date_added, dtype: str

# %%
netflix_data['date_added']=pd.to_datetime(netflix_data['date_added'].str.strip())

# %%
netflix_data['added_year']=netflix_data['date_added'].dt.year
netflix_data['added_year'].head()
# Out:
# 0    2021
# 1    2021
# 2    2021
# 3    2021
# 4    2021
# Name: added_year, dtype: int32

# %%
netflix_data['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2666
# Name: count, dtype: int64

# %%
netflix_data['country'].head(20)
# Out:
# 0                                         United States
# 1                                          South Africa
# 2                                                   NaN
# 3                                                   NaN
# 4                                                 India
# 5                                                   NaN
# 6                                                   NaN
# 7     United States, Ghana, Burkina Faso, United Kin...
# 8                                        United Kingdom
# 9                                         United States
# 10                                                  NaN
# 11                                                  NaN
# 12                              Germany, Czech Republic
# 13                                                  NaN
# 14                                                  NaN
# 15                                        United States
# 16                                                  NaN
# ...

# %%
netflix_data[netflix_data['country'].str.contains(',')]['country'].shape
# Out:
# (1320,)

# %%
netflix_data['listed_in'].head(20)
# Out:
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# 5                    TV Dramas, TV Horror, TV Mysteries
# 6                              Children & Family Movies
# 7      Dramas, Independent Movies, International Movies
# 8                          British TV Shows, Reality TV
# 9                                      Comedies, Dramas
# 10    Crime TV Shows, Docuseries, International TV S...
# 11    Crime TV Shows, International TV Shows, TV Act...
# 12                         Dramas, International Movies
# 13                   Children & Family Movies, Comedies
# 14         British TV Shows, Crime TV Shows, Docuseries
# 15                               TV Comedies, TV Dramas
# 16                  Documentaries, International Movies
# ...

# %%
netflix_data['rating'].head(20)
# Out:
# 0     PG-13
# 1     TV-MA
# 2     TV-MA
# 3     TV-MA
# 4     TV-MA
# 5     TV-MA
# 6        PG
# 7     TV-MA
# 8     TV-14
# 9     PG-13
# 10    TV-MA
# 11    TV-MA
# 12    TV-MA
# 13    TV-PG
# 14    TV-MA
# 15    TV-MA
# 16    TV-MA
# 17    TV-MA
# 18    TV-14
# 19    TV-MA
# Name: rating, dtype: str

# %%
netflix_data['rating'].value_counts()
# Out:
# rating
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
list_s=['84 min','74 min','66 min']
netflix_data[netflix_data['rating'].isin(list_s)]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min      NaN
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min      NaN
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min      NaN
#
#      listed_in                                        description  added_year
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...        2017
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...        2016
# 5813    Movies  The comic puts his trademark hilarious/thought...        2016

# %%
netflix_data['duration']=netflix_data['rating'].where(netflix_data['rating'].isin(list_s),netflix_data['duration'])
netflix_data.loc[netflix_data['rating'].isin(list_s),'rating']=pd.NA
netflix_data['rating'].value_counts()
# Out:
# rating
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %%
netflix_data['duration'].head(20)
# Out:
# 0        90 min
# 1     2 Seasons
# 2      1 Season
# 3      1 Season
# 4     2 Seasons
# 5      1 Season
# 6        91 min
# 7       125 min
# 8     9 Seasons
# 9       104 min
# 10     1 Season
# 11     1 Season
# 12      127 min
# 13       91 min
# 14     1 Season
# 15    4 Seasons
# 16       67 min
# 17    2 Seasons
# 18       94 min
# 19     1 Season
# Name: duration, dtype: str

# %%
netflix_data.to_csv('C:\\Users\\dawit\\PycharmProjects\\Netflix Content Evolution\\data\\netflix_cleaned.csv',index=False)
